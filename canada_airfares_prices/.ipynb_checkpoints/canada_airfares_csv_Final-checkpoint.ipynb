# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# dataset from https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=2310023701

airfare_price = "Resources/airfares_per_city_quarterly.csv"

# %%
airfare_price = pd.read_csv(airfare_price)
airfare_price
# Out:
#      REF_DATE        GEO           DGUID      UOM  UOM_ID SCALAR_FACTOR  \
# 0     1983-01     Canada  2016A000011124  Dollars      81        units
# 1     1983-01    Halifax             NaN  Dollars      81        units
# 2     1983-01   Montréal             NaN  Dollars      81        units
# 3     1983-01     Ottawa             NaN  Dollars      81        units
# 4     1983-01    Toronto             NaN  Dollars      81        units
# ...       ...        ...             ...      ...     ...           ...
# 1601  2019-04  Saskatoon             NaN  Dollars      81         units
# 1602  2019-04     Regina             NaN  Dollars      81         units
# 1603  2019-04    Calgary             NaN  Dollars      81         units
# 1604  2019-04   Edmonton             NaN  Dollars      81         units
# 1605  2019-04  Vancouver             NaN  Dollars      81         units
#
#       SCALAR_ID   VECTOR  COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  \
# 0             0  v812690           1  119.8    NaN     NaN         NaN
# 1             0  v812700           2  115.8    NaN     NaN         NaN
# 2             0  v812699           3  109.2    NaN     NaN         NaN
# 3             0  v812698           4  107.9    NaN     NaN         NaN
# 4             0  v812697           5  137.7    NaN     NaN         NaN
# ...         ...      ...         ...    ...    ...     ...         ...
# 1601          0  v812695           7  163.5    NaN     NaN         NaN
# 1602          0  v812694           8  168.9    NaN     NaN         NaN
# 1603          0  v812693           9  162.5    NaN     NaN         NaN
# 1604          0  v812692          10  163.1    NaN     NaN         NaN
# 1605          0  v812691          11  198.9    NaN     NaN         NaN
#
#       DECIMALS
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 1601         2
# 1602         2
# 1603         2
# 1604         2
# 1605         2
#
# [1606 rows x 14 columns]

# %%
# split REF_DATE into Year and Quarter

airfare_price[["Year","Quarter"]] = airfare_price.REF_DATE.str.split("-", expand = True)

airfare_price_cleaned = airfare_price[["Year","Quarter","GEO","VALUE","UOM"]]

airfare_price_cleaned
# Out:
#       Year Quarter        GEO  VALUE      UOM
# 0     1983      01     Canada  119.8  Dollars
# 1     1983      01    Halifax  115.8  Dollars
# 2     1983      01   Montréal  109.2  Dollars
# 3     1983      01     Ottawa  107.9  Dollars
# 4     1983      01    Toronto  137.7  Dollars
# ...    ...     ...        ...    ...      ...
# 1601  2019      04  Saskatoon  163.5  Dollars
# 1602  2019      04     Regina  168.9  Dollars
# 1603  2019      04    Calgary  162.5  Dollars
# 1604  2019      04   Edmonton  163.1  Dollars
# 1605  2019      04  Vancouver  198.9  Dollars
#
# [1606 rows x 5 columns]

# %%
# rename columns names

airfare_price_cleaned = airfare_price_cleaned.rename(columns={"GEO":"City", "VALUE":"Avg Price", "UOM":"Currency"})

# %%
# Adjust quarter's values 

airfare_price_cleaned = airfare_price_cleaned.replace({"01":1 , "04":2 , "07":3 , "10":4})

# %%
# converting "Year" values from string to integer

airfare_price_cleaned["Year"] = airfare_price_cleaned["Year"].astype(int)

# %%
airfare_price_cleaned
# Out:
#       Year  Quarter       City  Avg Price Currency
# 0     1983        1     Canada      119.8  Dollars
# 1     1983        1    Halifax      115.8  Dollars
# 2     1983        1   Montréal      109.2  Dollars
# 3     1983        1     Ottawa      107.9  Dollars
# 4     1983        1    Toronto      137.7  Dollars
# ...    ...      ...        ...        ...      ...
# 1601  2019        2  Saskatoon      163.5  Dollars
# 1602  2019        2     Regina      168.9  Dollars
# 1603  2019        2    Calgary      162.5  Dollars
# 1604  2019        2   Edmonton      163.1  Dollars
# 1605  2019        2  Vancouver      198.9  Dollars
#
# [1606 rows x 5 columns]

# %%
# filtering the dataset only for the required cities and period range (2015 to 2019)

cities_filtered = airfare_price_cleaned.loc[(((airfare_price_cleaned["City"] == "Toronto") |\
                                             (airfare_price_cleaned["City"] == "Vancouver") |\
                                             (airfare_price_cleaned["City"] == "Montréal") |\
                                             (airfare_price_cleaned["City"] == "Halifax")) &\
                                             (airfare_price_cleaned["Year"] >= 2015)), :]

# %%
cities_filtered
# Out:
#       Year  Quarter       City  Avg Price Currency
# 1409  2015        1    Halifax      192.1  Dollars
# 1410  2015        1   Montréal      176.3  Dollars
# 1412  2015        1    Toronto      215.1  Dollars
# 1418  2015        1  Vancouver      201.2  Dollars
# 1420  2015        2    Halifax      170.2  Dollars
# ...    ...      ...        ...        ...      ...
# 1594  2019        1  Vancouver      190.0  Dollars
# 1596  2019        2    Halifax      167.9  Dollars
# 1597  2019        2   Montréal      175.6  Dollars
# 1599  2019        2    Toronto      203.2  Dollars
# 1605  2019        2  Vancouver      198.9  Dollars
#
# [72 rows x 5 columns]

# %%
cities = ["Halifax", "Montréal", "Toronto", "Vancouver"]

# %%
city_airfares = []

# %%
# grouping data by City and Quarter

avg_airfare = cities_filtered.groupby(by=["City","Quarter"]).mean()

# %%
avg_airfare = avg_airfare["Avg Price"]

avg_airfare
# Out:
# City       Quarter
# Halifax    1          164.460
#            2          158.400
#            3          172.075
#            4          157.525
# Montréal   1          165.840
#            2          167.500
#            3          161.200
#            4          165.625
# Toronto    1          198.720
#            2          194.320
#            3          192.450
#            4          194.325
# Vancouver  1          191.960
#            2          191.720
#            3          198.075
#            4          189.625
# Name: Avg Price, dtype: float64

# %%
avg_airfare_df = pd.DataFrame(avg_airfare)

avg_airfare_df
# Out:
#                    Avg Price
# City      Quarter
# Halifax   1          164.460
#           2          158.400
#           3          172.075
#           4          157.525
# Montréal  1          165.840
#           2          167.500
#           3          161.200
#           4          165.625
# Toronto   1          198.720
#           2          194.320
#           3          192.450
#           4          194.325
# Vancouver 1          191.960
#           2          191.720
#           3          198.075
#           4          189.625

# %%
dataframe = avg_airfare_df.reset_index()

dataframe = pd.DataFrame(dataframe)

# %%
df = dataframe.set_index("City")

# %%
df
# Out:
#            Quarter  Avg Price
# City
# Halifax          1    164.460
# Halifax          2    158.400
# Halifax          3    172.075
# Halifax          4    157.525
# Montréal         1    165.840
# Montréal         2    167.500
# Montréal         3    161.200
# Montréal         4    165.625
# Toronto          1    198.720
# Toronto          2    194.320
# Toronto          3    192.450
# Toronto          4    194.325
# Vancouver        1    191.960
# Vancouver        2    191.720
# Vancouver        3    198.075
# Vancouver        4    189.625

# %%
city_avg_price2 = []

# %%
for city in cities:
    test2 = dataframe.loc[dataframe["City"] == city, ["City","Quarter","Avg Price"]]
    city_avg_price2.append(test2)

# %%
# city_avg_price2

# %%
# quarters = [1, 2, 3, 4]

# %%
plt.plot(city_avg_price2[0]["Quarter"], city_avg_price2[0]["Avg Price"])

plt.plot(city_avg_price2[1]["Quarter"], city_avg_price2[1]["Avg Price"])

plt.plot(city_avg_price2[2]["Quarter"], city_avg_price2[2]["Avg Price"])

plt.plot(city_avg_price2[3]["Quarter"], city_avg_price2[3]["Avg Price"])

plt.title("Average airfare price per city (2015 to 2019) - Quarterly")
plt.xticks(df["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=45)
# plt.xlabel("Year Quarter")
# plt.xlim(0.5, 4.5, 1)
plt.ylim(155, 205, 10)
plt.ylabel("Average Airfare Price ($)")
plt.legend(cities)
plt.grid()

plt.show()

# %%
# dataset imported from https://open.canada.ca/data/en/dataset/f87a464e-7d08-4f40-a4c7-d76ce8008fd8

airfare_group = "Resources/airfare_per_group.csv"

# %%
airfare_group_df = pd.read_csv(airfare_group)

airfare_group_df.head()
# Out:
#   REF_DATE     GEO           DGUID                      Sector  \
# 0  2007-01  Canada  2016A000011124  Domestic and international
# 1  2007-01  Canada  2016A000011124  Domestic and international
# 2  2007-01  Canada  2016A000011124  Domestic and international
# 3  2007-01  Canada  2016A000011124  Domestic and international
# 4  2007-01  Canada  2016A000011124  Domestic and international
#
#    Fare type group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  \
# 0  All fare groups  Dollars      81        units           0  v53508617
# 1   Business class  Dollars      81        units           0  v53508618
# 2          Economy  Dollars      81        units           0  v53508619
# 3       Discounted  Dollars      81        units           0  v53508620
# 4      Other fares  Dollars      81        units           0  v53508621
#
#   COORDINATE   VALUE STATUS  SYMBOL TERMINATED  DECIMALS
# 0      1.1.1   238.0    NaN     NaN        NaN         2
# 1      1.1.2  2398.3      E     NaN          t         2
# 2      1.1.3   252.8    NaN     NaN          t         2
# 3      1.1.4   238.1    NaN     NaN          t         2
# 4      1.1.5    87.3      E     NaN          t         2

# %%
airfare_group_df[["Year","Quarter"]] = airfare_group_df.REF_DATE.str.split("-", expand = True)

airfare_group_cleaned = airfare_group_df[["Year","Quarter","Sector","Fare type group", "VALUE", "UOM"]]

airfare_group_cleaned
# Out:
#       Year Quarter                      Sector  Fare type group   VALUE  \
# 0     2007      01  Domestic and international  All fare groups   238.0
# 1     2007      01  Domestic and international   Business class  2398.3
# 2     2007      01  Domestic and international          Economy   252.8
# 3     2007      01  Domestic and international       Discounted   238.1
# 4     2007      01  Domestic and international      Other fares    87.3
# ...    ...     ...                         ...              ...     ...
# 1205  2019      04  Domestic and international  All fare groups   239.3
# 1206  2019      04                    Domestic  All fare groups   176.6
# 1207  2019      04                  Short-haul  All fare groups   125.8
# 1208  2019      04                   Long-haul  All fare groups   224.5
# 1209  2019      04               International  All fare groups   300.6
#
#           UOM
# 0     Dollars
# 1     Dollars
# 2     Dollars
# 3     Dollars
# 4     Dollars
# ...       ...
# 1205  Dollars
# 1206  Dollars
# 1207  Dollars
# 1208  Dollars
# 1209  Dollars
#
# [1210 rows x 6 columns]

# %%
airfare_group_cleaned = airfare_group_cleaned.rename(columns={"Fare type group":"Fare Type", "VALUE":"Avg Price", "UOM":"Currency"})

airfare_group_cleaned
# Out:
#       Year Quarter                      Sector        Fare Type  Avg Price  \
# 0     2007      01  Domestic and international  All fare groups      238.0
# 1     2007      01  Domestic and international   Business class     2398.3
# 2     2007      01  Domestic and international          Economy      252.8
# 3     2007      01  Domestic and international       Discounted      238.1
# 4     2007      01  Domestic and international      Other fares       87.3
# ...    ...     ...                         ...              ...        ...
# 1205  2019      04  Domestic and international  All fare groups      239.3
# 1206  2019      04                    Domestic  All fare groups      176.6
# 1207  2019      04                  Short-haul  All fare groups      125.8
# 1208  2019      04                   Long-haul  All fare groups      224.5
# 1209  2019      04               International  All fare groups      300.6
#
#      Currency
# 0     Dollars
# 1     Dollars
# 2     Dollars
# 3     Dollars
# 4     Dollars
# ...       ...
# 1205  Dollars
# 1206  Dollars
# 1207  Dollars
# 1208  Dollars
# 1209  Dollars
#
# [1210 rows x 6 columns]

# %%
airfare_group_cleaned = airfare_group_cleaned.replace({"01":1 , "04":2 , "07":3 , "10":4})

# %%
# converting "Year" values to integer

airfare_group_cleaned["Year"] = airfare_group_cleaned["Year"].astype(int)

# %%
airfare_group_cleaned["Sector"].value_counts()
# Out:
# International                 242
# Domestic and international    242
# Long-haul                     242
# Domestic                      242
# Short-haul                    242
# Name: Sector, dtype: int64

# %%
airfare_group_cleaned["Fare Type"].value_counts()
# Out:
# All fare groups    250
# Discounted         240
# Other fares        240
# Economy            240
# Business class     240
# Name: Fare Type, dtype: int64

# %%
# filtering the dataset only for the required cities and period range (2015 to 2019)

airfares_filtered = airfare_group_cleaned.loc[((airfare_group_cleaned["Sector"] == "Domestic") &\
                                               ((airfare_group_cleaned["Fare Type"] == "Discounted") |\
                                                (airfare_group_cleaned["Fare Type"] == "Other fares") |\
                                               (airfare_group_cleaned["Fare Type"] == "Economy")) &\
                                               (airfare_group_cleaned["Year"] >= 2015)), :]


airfares_filtered
# Out:
#       Year  Quarter    Sector    Fare Type  Avg Price Currency
# 807   2015        1  Domestic      Economy        NaN  Dollars
# 808   2015        1  Domestic   Discounted      180.3  Dollars
# 809   2015        1  Domestic  Other fares      173.6  Dollars
# 832   2015        2  Domestic      Economy      272.0  Dollars
# 833   2015        2  Domestic   Discounted      172.5  Dollars
# 834   2015        2  Domestic  Other fares      164.5  Dollars
# 857   2015        3  Domestic      Economy      285.5  Dollars
# 858   2015        3  Domestic   Discounted      174.1  Dollars
# 859   2015        3  Domestic  Other fares      188.3  Dollars
# 882   2015        4  Domestic      Economy      279.0  Dollars
# 883   2015        4  Domestic   Discounted      172.5  Dollars
# 884   2015        4  Domestic  Other fares      166.9  Dollars
# 907   2016        1  Domestic      Economy        NaN  Dollars
# 908   2016        1  Domestic   Discounted      165.1  Dollars
# 909   2016        1  Domestic  Other fares      150.0  Dollars
# 932   2016        2  Domestic      Economy      300.7  Dollars
# 933   2016        2  Domestic   Discounted      163.0  Dollars
# 934   2016        2  Domestic  Other fares      139.5  Dollars
# 957   2016        3  Domestic      Economy      308.3  Dollars
# 958   2016        3  Domestic   Discounted      172.1  Dollars
# 959   2016        3  Domestic  Other fares      175.6  Dollars
# 982   2016        4  Domestic      Economy      262.3  Dollars
# 983   2016        4  Domestic   Discounted      162.0  Dollars
# 984   2016        4  Domestic  Other fares      156.9  Dollars
# 1007  2017        1  Domestic      Economy      267.2  Dollars
# 1008  2017        1  Domestic   Discounted      161.7  Dollars
# 1009  2017        1  Domestic  Other fares      158.5  Dollars
# 1032  2017        2  Domestic      Economy      312.5  Dollars
# 1033  2017        2  Domestic   Discounted      165.6  Dollars
# 1034  2017        2  Domestic  Other fares      157.8  Dollars
# 1057  2017        3  Domestic      Economy      327.4  Dollars
# 1058  2017        3  Domestic   Discounted      169.7  Dollars
# 1059  2017        3  Domestic  Other fares      156.7  Dollars
# 1082  2017        4  Domestic      Economy      286.9  Dollars
# 1083  2017        4  Domestic   Discounted      167.4  Dollars
# 1084  2017        4  Domestic  Other fares      144.8  Dollars
# 1107  2018        1  Domestic      Economy      265.6  Dollars
# 1108  2018        1  Domestic   Discounted      161.7  Dollars
# 1109  2018        1  Domestic  Other fares      155.1  Dollars
# 1132  2018        2  Domestic      Economy      298.7  Dollars
# 1133  2018        2  Domestic   Discounted      159.3  Dollars
# 1134  2018        2  Domestic  Other fares      153.4  Dollars
# 1157  2018        3  Domestic      Economy        NaN  Dollars
# 1158  2018        3  Domestic   Discounted      165.6  Dollars
# 1159  2018        3  Domestic  Other fares      175.2  Dollars
# 1182  2018        4  Domestic      Economy        NaN  Dollars
# 1183  2018        4  Domestic   Discounted      165.6  Dollars
# 1184  2018        4  Domestic  Other fares      112.0  Dollars

# %%
airfares_filtered["Fare Type"].value_counts()
# Out:
# Discounted     16
# Other fares    16
# Economy        16
# Name: Fare Type, dtype: int64

# %%
airfares_valid = airfares_filtered.dropna(how="any")

airfares_valid
# Out:
#       Year  Quarter    Sector    Fare Type  Avg Price Currency
# 808   2015        1  Domestic   Discounted      180.3  Dollars
# 809   2015        1  Domestic  Other fares      173.6  Dollars
# 832   2015        2  Domestic      Economy      272.0  Dollars
# 833   2015        2  Domestic   Discounted      172.5  Dollars
# 834   2015        2  Domestic  Other fares      164.5  Dollars
# 857   2015        3  Domestic      Economy      285.5  Dollars
# 858   2015        3  Domestic   Discounted      174.1  Dollars
# 859   2015        3  Domestic  Other fares      188.3  Dollars
# 882   2015        4  Domestic      Economy      279.0  Dollars
# 883   2015        4  Domestic   Discounted      172.5  Dollars
# 884   2015        4  Domestic  Other fares      166.9  Dollars
# 908   2016        1  Domestic   Discounted      165.1  Dollars
# 909   2016        1  Domestic  Other fares      150.0  Dollars
# 932   2016        2  Domestic      Economy      300.7  Dollars
# 933   2016        2  Domestic   Discounted      163.0  Dollars
# 934   2016        2  Domestic  Other fares      139.5  Dollars
# 957   2016        3  Domestic      Economy      308.3  Dollars
# 958   2016        3  Domestic   Discounted      172.1  Dollars
# 959   2016        3  Domestic  Other fares      175.6  Dollars
# 982   2016        4  Domestic      Economy      262.3  Dollars
# 983   2016        4  Domestic   Discounted      162.0  Dollars
# 984   2016        4  Domestic  Other fares      156.9  Dollars
# 1007  2017        1  Domestic      Economy      267.2  Dollars
# 1008  2017        1  Domestic   Discounted      161.7  Dollars
# 1009  2017        1  Domestic  Other fares      158.5  Dollars
# 1032  2017        2  Domestic      Economy      312.5  Dollars
# 1033  2017        2  Domestic   Discounted      165.6  Dollars
# 1034  2017        2  Domestic  Other fares      157.8  Dollars
# 1057  2017        3  Domestic      Economy      327.4  Dollars
# 1058  2017        3  Domestic   Discounted      169.7  Dollars
# 1059  2017        3  Domestic  Other fares      156.7  Dollars
# 1082  2017        4  Domestic      Economy      286.9  Dollars
# 1083  2017        4  Domestic   Discounted      167.4  Dollars
# 1084  2017        4  Domestic  Other fares      144.8  Dollars
# 1107  2018        1  Domestic      Economy      265.6  Dollars
# 1108  2018        1  Domestic   Discounted      161.7  Dollars
# 1109  2018        1  Domestic  Other fares      155.1  Dollars
# 1132  2018        2  Domestic      Economy      298.7  Dollars
# 1133  2018        2  Domestic   Discounted      159.3  Dollars
# 1134  2018        2  Domestic  Other fares      153.4  Dollars
# 1158  2018        3  Domestic   Discounted      165.6  Dollars
# 1159  2018        3  Domestic  Other fares      175.2  Dollars
# 1183  2018        4  Domestic   Discounted      165.6  Dollars
# 1184  2018        4  Domestic  Other fares      112.0  Dollars

# %%
airfares_grouped = airfares_valid.groupby(by=["Quarter"]).mean()

# %%
airfares_grouped = airfares_grouped["Avg Price"]

# %%
dataframe2 = airfares_grouped.reset_index()

dataframe2 = pd.DataFrame(dataframe2)

# %%
df2 = dataframe2.set_index(["Quarter"])

# %%
df2
# Out:
#           Avg Price
# Quarter
# 1        183.880000
# 2        204.958333
# 3        208.954545
# 4        188.754545

# %% [markdown]
# ## Airfare Charts

# %%
# Chart for Halifax

plt.plot(city_avg_price2[0]["Quarter"], city_avg_price2[0]["Avg Price"])

plt.title("Average airfare price for Halifax (2015 to 2019) - Quarterly")
plt.xticks(df["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
plt.ylim(155, 205, 10)
plt.ylabel("Average Airfare Price ($)")
# plt.legend("Halifax", loc=2)
plt.grid()

plt.savefig("output/airfare_halifax.png", dpi=100)

# %%
# Chart for Montréal

plt.plot(city_avg_price2[1]["Quarter"], city_avg_price2[1]["Avg Price"], color="orange")

plt.title("Average airfare price for Montréal (2015 to 2019) - Quarterly")
plt.xticks(df["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
plt.ylim(155, 205, 10)
plt.ylabel("Average Airfare Price ($)")
# plt.legend("Halifax", loc=2)
plt.grid()

plt.savefig("output/airfare_montreal.png", dpi=100)

# %%
# Chart for Toronto

plt.plot(city_avg_price2[2]["Quarter"], city_avg_price2[2]["Avg Price"], color="g")

plt.title("Average airfare price for Toronto (2015 to 2019) - Quarterly")
plt.xticks(df["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
plt.ylim(155, 205, 10)
plt.ylabel("Average Airfare Price ($)")
plt.grid()

plt.savefig("output/airfare_toronto.png", dpi=100)

# %%
# Chart for Vancouver

plt.plot(city_avg_price2[3]["Quarter"], city_avg_price2[3]["Avg Price"], color="r")

plt.title("Average airfare price for Vancouver (2015 to 2019) - Quarterly")
plt.xticks(df["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
plt.ylim(155, 205, 10)
plt.ylabel("Average Airfare Price ($)")
plt.grid()

plt.savefig("output/airfare_vancouver.png", dpi=100)

# %%
average_line = ["average low fares"]
legend = cities + average_line

# %%
plt.plot(city_avg_price2[0]["Quarter"], city_avg_price2[0]["Avg Price"])

plt.plot(city_avg_price2[1]["Quarter"], city_avg_price2[1]["Avg Price"])

plt.plot(city_avg_price2[2]["Quarter"], city_avg_price2[2]["Avg Price"])

plt.plot(city_avg_price2[3]["Quarter"], city_avg_price2[3]["Avg Price"])

plt.plot(df2)

plt.title("Average airfare price per city (2015 to 2019) - Quarterly")
plt.xticks(df2.index, ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
plt.ylim(155, 225, 10)
plt.ylabel("Average Airfare Price ($)")
plt.legend(legend, ncol=3)
plt.grid()
# plt.figure(figsize=(20, 20))
plt.savefig("output/airfare_comparison.png", dpi=100)
